# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def lastSpeed(vi,a,t):
    vf = float(vi + a*t)
    print(vf)
lastSpeed(float(input("enter first speed:")),float(input("enter accelaretion:")),float(input("enter time:")))
# Out:
# 188.0

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def perfectNumber(number):
    total = 0
    for i in range(1,number) :
        if number % i == 0:
            total+=i
    if total == number:
        return True
    else:
        return False 
for number in range(1,1001):
    if perfectNumber(number):
        print(f"{number} is a perfect number.")
# Out:
# 6 is a perfect number.
# 28 is a perfect number.
# 496 is a perfect number.

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
# 3.Problemin Çözümünü Buraya Yazınız
def square(number):
    return number*number
def pisagor(a,b):
    c_square = square(a) + square(b)
    c = int(c_square**0.5)
    
    return c_square == square(c)
     
for a in range(1,101):
    for b in range(1,101):
        if pisagor(a,b):
            print(f"{a} and {b} makes pisagor triangle.")
# Out:
# 3 and 4 makes pisagor triangle.
# 4 and 3 makes pisagor triangle.
# 5 and 12 makes pisagor triangle.
# 6 and 8 makes pisagor triangle.
# 7 and 24 makes pisagor triangle.
# 8 and 6 makes pisagor triangle.
# 8 and 15 makes pisagor triangle.
# 9 and 12 makes pisagor triangle.
# 9 and 40 makes pisagor triangle.
# 10 and 24 makes pisagor triangle.
# 11 and 60 makes pisagor triangle.
# 12 and 5 makes pisagor triangle.
# 12 and 9 makes pisagor triangle.
# 12 and 16 makes pisagor triangle.
# 12 and 35 makes pisagor triangle.
# 13 and 84 makes pisagor triangle.
# 14 and 48 makes pisagor triangle.
# 15 and 8 makes pisagor triangle.
# 15 and 20 makes pisagor triangle.
# 15 and 36 makes pisagor triangle.
# 16 and 12 makes pisagor triangle.
# 16 and 30 makes pisagor triangle.
# 16 and 63 makes pisagor triangle.
# 18 and 24 makes pisagor triangle.
# 18 and 80 makes pisagor triangle.
# 20 and 15 makes pisagor triangle.
# 20 and 21 makes pisagor triangle.
# 20 and 48 makes pisagor triangle.
# 20 and 99 makes pisagor triangle.
# 21 and 20 makes pisagor triangle.
# 21 and 28 makes pisagor triangle.
# 21 and 72 makes pisagor triangle.
# 24 and 7 makes pisagor triangle.
# 24 and 10 makes pisagor triangle.
# 24 and 18 makes pisagor triangle.
# 24 and 32 makes pisagor triangle.
# 24 and 45 makes pisagor triangle.
# 24 and 70 makes pisagor triangle.
# 25 and 60 makes pisagor triangle.
# 27 and 36 makes pisagor triangle.
# 28 and 21 makes pisagor triangle.
# 28 and 45 makes pisagor triangle.
# 28 and 96 makes pisagor triangle.
# 30 and 16 makes pisagor triangle.
# 30 and 40 makes pisagor triangle.
# 30 and 72 makes pisagor triangle.
# 32 and 24 makes pisagor triangle.
# 32 and 60 makes pisagor triangle.
# 33 and 44 makes pisagor triangle.
# 33 and 56 makes pisagor triangle.
# 35 and 12 makes pisagor triangle.
# 35 and 84 makes pisagor triangle.
# 36 and 15 makes pisagor triangle.
# 36 and 27 makes pisagor triangle.
# 36 and 48 makes pisagor triangle.
# 36 and 77 makes pisagor triangle.
# 39 and 52 makes pisagor triangle.
# 39 and 80 makes pisagor triangle.
# 40 and 9 makes pisagor triangle.
# 40 and 30 makes pisagor triangle.
# 40 and 42 makes pisagor triangle.
# 40 and 75 makes pisagor triangle.
# 40 and 96 makes pisagor triangle.
# 42 and 40 makes pisagor triangle.
# 42 and 56 makes pisagor triangle.
# 44 and 33 makes pisagor triangle.
# 45 and 24 makes pisagor triangle.
# 45 and 28 makes pisagor triangle.
# 45 and 60 makes pisagor triangle.
# 48 and 14 makes pisagor triangle.
# 48 and 20 makes pisagor triangle.
# 48 and 36 makes pisagor triangle.
# 48 and 55 makes pisagor triangle.
# 48 and 64 makes pisagor triangle.
# 48 and 90 makes pisagor triangle.
# 51 and 68 makes pisagor triangle.
# 52 and 39 makes pisagor triangle.
# 54 and 72 makes pisagor triangle.
# 55 and 48 makes pisagor triangle.
# 56 and 33 makes pisagor triangle.
# 56 and 42 makes pisagor triangle.
# 56 and 90 makes pisagor triangle.
# 57 and 76 makes pisagor triangle.
# 60 and 11 makes pisagor triangle.
# 60 and 25 makes pisagor triangle.
# 60 and 32 makes pisagor triangle.
# 60 and 45 makes pisagor triangle.
# 60 and 63 makes pisagor triangle.
# 60 and 80 makes pisagor triangle.
# 60 and 91 makes pisagor triangle.
# 63 and 16 makes pisagor triangle.
# 63 and 60 makes pisagor triangle.
# 63 and 84 makes pisagor triangle.
# 64 and 48 makes pisagor triangle.
# 65 and 72 makes pisagor triangle.
# 66 and 88 makes pisagor triangle.
# 68 and 51 makes pisagor triangle.
# 69 and 92 makes pisagor triangle.
# 70 and 24 makes pisagor triangle.
# 72 and 21 makes pisagor triangle.
# 72 and 30 makes pisagor triangle.
# 72 and 54 makes pisagor triangle.
# 72 and 65 makes pisagor triangle.
# 72 and 96 makes pisagor triangle.
# 75 and 40 makes pisagor triangle.
# 75 and 100 makes pisagor triangle.
# 76 and 57 makes pisagor triangle.
# 77 and 36 makes pisagor triangle.
# 80 and 18 makes pisagor triangle.
# 80 and 39 makes pisagor triangle.
# 80 and 60 makes pisagor triangle.
# 80 and 84 makes pisagor triangle.
# 84 and 13 makes pisagor triangle.
# 84 and 35 makes pisagor triangle.
# 84 and 63 makes pisagor triangle.
# 84 and 80 makes pisagor triangle.
# 88 and 66 makes pisagor triangle.
# 90 and 48 makes pisagor triangle.
# 90 and 56 makes pisagor triangle.
# 91 and 60 makes pisagor triangle.
# 92 and 69 makes pisagor triangle.
# 96 and 28 makes pisagor triangle.
# 96 and 40 makes pisagor triangle.
# 96 and 72 makes pisagor triangle.
# 99 and 20 makes pisagor triangle.
# 100 and 75 makes pisagor triangle.

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
# 4.Problemin Çözümünü Buraya Yazınız   
def boxNumber(h,w):
    bow_number = (h*w)/5
    if bow_number != int(bow_number):
        bow_number = int(bow_number) + 1
        print(bow_number)
    else:
        print(int(bow_number))
boxNumber(float(input("please enter height:")),float(input("please enter weight:")))
# Out:
# 1

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
unluHarfler = ["a","e","i","o","u"]

def unluHarf(word):
    toplam = 0
    for i in word:
        for j in unluHarfler:
            if i == j:
                toplam += 1
    print(toplam)
unluHarf(input("Bir kelime yaziniz."))
# Out:
# 3

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
liste = []
n = int(input("Listenin eleman sayisi:"))
for i in range(n):
    number = int(input(f"{i+1}. eleman:"))
    liste.append(number)

def findEven(liste):
    for i in liste:
        if i % 2 == 0:
            print(i)
findEven(liste)
# Out:
# 2
# 4
# 6

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
# 7.Problemin Çözümünü Buraya Yazınız
def recursiveFunction(number):
    if number == 0:
        return 0
    else:
        return number + recursiveFunction(number-1)
recursiveFunction(10)
# Out:
# 55
