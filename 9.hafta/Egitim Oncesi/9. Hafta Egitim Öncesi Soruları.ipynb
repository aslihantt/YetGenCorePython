# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

class Bus(Vehicle):
    def __init__(self, make, model, year, seating_capacity=50):
        super().__init__(make, model, year)
        self.seating_capacity = seating_capacity

    def seating_capacity(self):
        return self.seating_capacity

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

class Bus(Vehicle):
    def __init__(self, make, model, year, seating_capacity=50):
        super().__init__(make, model, year)
        self.seating_capacity = seating_capacity

    def seating_capacity(self):
        return self.seating_capacity
        
School_bus = Bus("Mercedes-Benz", "Sprinter", 2021, 30)
